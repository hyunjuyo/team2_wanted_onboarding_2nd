# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sanghyun\\Desktop\\Fst_week_demo\\team2_wanted_onboarding_2nd\\Week1_정상현'

# %% [markdown]
# ## <U> 유니콘 기업의 정의 </U>
# ### 기업가치가 10억 달러 이상인 비상장 스타트업을 이르는 말 (출처 : 나무위키)
# ### 인터넷을 검색하다보면 매출은 얼마 안되는 반면, 가치가 수천 억에 달하는 스타트업들을 종종 볼 수 있다.
# ### 기업 가치는 매출만으로 정해지지 않기 때문이다.
# ### 오히려 매출과 수익이 안정적으로 발생하는 기업이라면투자를 받을 이유가 덜할 것이다.
# ### 기업 가치 평가는 시장규모와 시장점유율, 현금 유동성, 기술 혁신성, 대표의 야망 등을
# ### 종합적으로 고려하여 진행된다. 따라서 언제든지 아래 기업들의 순위가 뒤바뀔 가능성이 크다.

# %%
df1=pd.read_csv('company_nps_data.csv',encoding='euc-kr')

# %% [markdown]
# ## <U>*진행방향*</U>
# ### <U>Route1</U>
# ### cb insight에서 유니콘 기업이라고 발표한 기업들의 연간매출성장률의 평균을 사람인에서 얻었습니다. 그리고 그 기준으로 주어진 데이터의 년별 매출성장률을 필터링하여 유니콘기업의 매출성장률 평균의 기준에 해당되는 업체를 선별했습니다.
#
#
# ### <U>Route2</U>
# ### iforest모델로 이상값을 구하고 (1) 직원별 매출액과 (2) 보험료1원당 매출액(효율적인 임금세팅)의 상위 0.01%에 해당하는 그룹 중 outlier에 해당하는 기업들을 유니콘 기업이라고 판단했습니다.
# ### 그리고 위 두 기준에 모두 해당하는 기업을 최종적으로 유니콘기업이라고 판단하였습니다.
# ### 논리는 다음과 같습니다.
# ### 실제 유니콘 기업의 연간매출성장률과 부합하고, 해당 매출액이 비교적 직원당 높은 효율을 바탕으로 이루어졌다.
# ### 그리고, 임금과 연동된 보험료당 높은 매출액을 얻는것으로 보아 효율적인 임금구조(고임금의 매출액상승에 기여하지 않는 높은 호봉 관리자가 없음)를 가지고 있다.
# ### 마지막으로, 5천개중에 5개정도의 유니콘을 찾으라는 과제이므로 일반적인 기업과 다른 예외적인 기업이 될 것이기에
# ### 스케일조정이나 인코딩의 영향을 덜 받는 iforest를 사용하였습니다.

# %%
# null값 없음
df1.isnull().sum()
# Out:
# 회사ID        0
# 연매출액        0
# 년도          0
# 월           0
# 월별_연금보험료    0
# 월별_직원수      0
# dtype: int64

# %% [markdown]
# 월별직원수의 편차가 크고 년도가 2015년부터 2019년까지로 년도 컬럼이 구성됨

# %%
df1.describe()
# Out:
#                회사ID          연매출액            년도             월      월별_연금보험료  \
# count  9.980100e+04  9.980100e+04  99801.000000  99801.000000  9.980100e+04
# mean   2.762982e+05  3.053589e+07   2016.967125      6.714352  9.734079e+06
# std    1.339032e+05  3.016647e+08      0.976688      3.512966  4.347256e+07
# min    6.300000e+01 -7.882176e+06   2015.000000      1.000000  0.000000e+00
# 25%    1.655300e+05  1.409760e+06   2016.000000      4.000000  1.181160e+06
# 50%    2.591490e+05  3.573585e+06   2017.000000      7.000000  2.332760e+06
# 75%    3.826560e+05  9.582321e+06   2018.000000     10.000000  5.591860e+06
# max    5.159723e+06  1.132878e+10   2019.000000     12.000000  9.780673e+08
#
#              월별_직원수
# count  99801.000000
# mean      37.623431
# std      146.947194
# min        0.000000
# 25%        6.000000
# 50%       11.000000
# 75%       24.000000
# max     3133.000000

# %% [markdown]
# ### 과제 : 5천개 회사중에 유니콘 찾기 - 최소 5개
# * 변수는 1.매출액, 2.보혐료, 3.직원수, 4.날짜

# %%
len(df1.회사ID.unique())
# Out:
# 5000

# %% [markdown]
# * 연매출액은 연단위이므로, 다른 변수와 맞추고 향후 aggregation계산의 편의를 위해 12로 나눠서 월매출 변수도 생성함

# %%
df1['월별_매출액']=(df1.연매출액)/12
df1
# Out:
#          회사ID      연매출액    년도   월  월별_연금보험료  월별_직원수        월별_매출액
# 0      233757  41688077  2018   7   8912380      36  3.474006e+06
# 1      123464   1760695  2018   3    942380       5  1.467246e+05
# 2      342124   3221341  2018   7    781180       4  2.684451e+05
# 3      386420   4815584  2015  11   3795900      14  4.012987e+05
# 4      129243   9799736  2018  10  40724680     151  8.166447e+05
# ...       ...       ...   ...  ..       ...     ...           ...
# 99796  171439   4630622  2017   2   2402740      11  3.858852e+05
# 99797  239388   1045021  2018  10   1428800       9  8.708508e+04
# 99798  272304    181898  2018   3    392560       4  1.515817e+04
# 99799  362194   2100218  2018  12    874780       3  1.750182e+05
# 99800  124281    132900  2017  11    291940       5  1.107500e+04
#
# [99801 rows x 7 columns]

# %% [markdown]
# * 년도별 데이터가 2016년과 2018년에 제일 많고, 그에 비해19년, 15년은 상당히 적음
# * 월데이터까지 포함하여 라인차트로 시각화해서 볼 필요가 있음

# %%
df1.년도.value_counts().sort_index()
# Out:
# 2015     3586
# 2016    37685
# 2017    17806
# 2018    39872
# 2019      852
# Name: 년도, dtype: int64

# %%
# 일 데이터가 없기 때문에 임의로 1로 추가함
df1['일'] = 1

# %%
df1.columns
# Out:
# Index(['회사ID', '연매출액', '년도', '월', '월별_연금보험료', '월별_직원수', '월별_매출액', '일'], dtype='object')

# %%
df1.columns=['회사ID', '연매출액', 'year', 'month', '월별_연금보험료', '월별_직원수','월별_매출액','day']

# %%
# 날짜타입변환
df1['date']=pd.to_datetime(df1[['year','month','day']])
df1
# Out:
#          회사ID      연매출액  year  month  월별_연금보험료  월별_직원수        월별_매출액  day  \
# 0      233757  41688077  2018      7   8912380      36  3.474006e+06    1
# 1      123464   1760695  2018      3    942380       5  1.467246e+05    1
# 2      342124   3221341  2018      7    781180       4  2.684451e+05    1
# 3      386420   4815584  2015     11   3795900      14  4.012987e+05    1
# 4      129243   9799736  2018     10  40724680     151  8.166447e+05    1
# ...       ...       ...   ...    ...       ...     ...           ...  ...
# 99796  171439   4630622  2017      2   2402740      11  3.858852e+05    1
# 99797  239388   1045021  2018     10   1428800       9  8.708508e+04    1
# 99798  272304    181898  2018      3    392560       4  1.515817e+04    1
# 99799  362194   2100218  2018     12    874780       3  1.750182e+05    1
# 99800  124281    132900  2017     11    291940       5  1.107500e+04    1
#
#             date
# 0     2018-07-01
# 1     2018-03-01
# 2     2018-07-01
# 3     2015-11-01
# 4     2018-10-01
# ...          ...
# 99796 2017-02-01
# 99797 2018-10-01
# 99798 2018-03-01
# 99799 2018-12-01
# 99800 2017-11-01
#
# [99801 rows x 9 columns]

# %% [markdown]
# * 월 데이터까지 합쳐서 날짜데이터를 시각화해서 본 결과로 년도별추이가 있고 월별추이는 크지 않은 것으로 판단됨
# * 결과는 앞서 언급한 것처럼 2016년과 2018년에 3000건 이상이며 2017년은 절반수준, 2019년은 비교가 안될정도로 적음

# %%
df1.date.value_counts().sort_index().plot()

# %% [markdown]
# ### 규정
# *국민연금보험료는 기준월소득액 * 0.09로 계산하며,*
# *최저 33만원에서 최고금액은 524만원까지의 범위로 결정하게 됨*
# *따라서, 신고한 소득월액이 33만원보다 적으면 33만원을 기준소득월액으로 하고,*
# *524만원보다 많으면 524만원을 기준소득월액으로 함*

# %% [markdown]
# * 보험료를 직원수로 나눠서 월별 직원별 보험료(기준월소득액과 연동되는 변수로 추정함-임금과 연동되는 변수)*
# * 라는 변수를 만들었고 이를 시각화 함*
# * 시간이 지나면서 직원들에게 지급되는 보험료는 등락이 있지만, 증가하는 추세를 보임*
# * 상반기에는 낮고 하반기에 증가하는 경향을 보임*
# * 2018년에 회사의 수는 제일 많지만, 2017년에 비해 직원별 보험료가 낮아짐(회사의 수가 늘어나서 해당 결과가 발생한 것으로 추정)*
# * 그리고, 2019년에는 회사수가 제일 적지만 월별 직원별 보험료가 제일 높음(임금이 높은 기업이 많은것이 아닐까 추정함)*

# %%
#  규정에서 처럼 1인당 연금보험료는 임금과 연동되는 수치이기 떄문에, 직원당 임금을 다음과 같이 간접적으로 추정함
월별_직원별보험료=df1.월별_연금보험료/df1.월별_직원수
df1['월별_직원별보험료']=월별_직원별보험료
df1
# Out:
#          회사ID      연매출액  year  month  월별_연금보험료  월별_직원수        월별_매출액  day  \
# 0      233757  41688077  2018      7   8912380      36  3.474006e+06    1
# 1      123464   1760695  2018      3    942380       5  1.467246e+05    1
# 2      342124   3221341  2018      7    781180       4  2.684451e+05    1
# 3      386420   4815584  2015     11   3795900      14  4.012987e+05    1
# 4      129243   9799736  2018     10  40724680     151  8.166447e+05    1
# ...       ...       ...   ...    ...       ...     ...           ...  ...
# 99796  171439   4630622  2017      2   2402740      11  3.858852e+05    1
# 99797  239388   1045021  2018     10   1428800       9  8.708508e+04    1
# 99798  272304    181898  2018      3    392560       4  1.515817e+04    1
# 99799  362194   2100218  2018     12    874780       3  1.750182e+05    1
# 99800  124281    132900  2017     11    291940       5  1.107500e+04    1
#
#             date      월별_직원별보험료
# 0     2018-07-01  247566.111111
# 1     2018-03-01  188476.000000
# 2     2018-07-01  195295.000000
# 3     2015-11-01  271135.714286
# 4     2018-10-01  269699.867550
# ...          ...            ...
# 99796 2017-02-01  218430.909091
# 99797 2018-10-01  158755.555556
# 99798 2018-03-01   98140.000000
# 99799 2018-12-01  291593.333333
# 99800 2017-11-01   58388.000000
#
# [99801 rows x 10 columns]

# %%
df1['월별_직원별보험료'].describe()
# Out:
# count     99788.000000
# mean     222542.478314
# std       64355.289384
# min       26100.000000
# 25%      176628.571429
# 50%      223196.666667
# 75%      266722.500000
# max      479821.250000
# Name: 월별_직원별보험료, dtype: float64

# %%
# 직원별 보험료는 정규분포형태의 형태와 유사함
df1.월별_직원별보험료.hist()

# %% [markdown]
# *  직원별 보험료값(임금과 연동되는)은 최저 2만6천100원인데, 실제 규정된 보험료 최저값은 인당 33만원에 해당됨
# *  이는 최고값의 경우도 동일하게 524만원에 비해 훨씬 낮은 47만9821원으로, 데이터에서 0한자리수가 생략되었을 수도 있음

# %% [markdown]
# *  년월별 연금보험료는 2015년부터 19년까지는 전반적으로 증가하는 추세에 있으며
# *  상반기보다는 하반기에 증가하는 경향을 보임
# *  2016년과 2018년에 데이터가 타 년도에 비해 많았으나, 직원별보험료의 중앙값은 오히려 17년이나 19년보다 낮음

# %%
df1_pay_date=df1.groupby('date')['월별_직원별보험료'].median()
df1_pay_date.plot()

# %% [markdown]
# ## Route 1 : 매출성장률 기반 실제 유니콘기업의 최소 3개년 평균 매출액 성장률 이상의
# ##                  기업 필터링하기

# %%
demo =df1.groupby(['회사ID','year'])['월별_매출액'].sum()
demo
# Out:
# 회사ID       year
# 63.0       2018.0    1.132878e+10
# 95.0       2018.0    6.569474e+08
# 102.0      2018.0    4.951060e+08
# 295.0      2018.0    5.585113e+07
# 414.0      2018.0    1.973277e+07
#                          ...
# 2400284.0  2018.0    7.369868e+05
# 2437574.0  2018.0    1.783467e+04
# 2693684.0  2019.0    1.190380e+05
# 3312354.0  2019.0    6.048179e+05
# 5159723.0  2019.0    2.159915e+05
# Name: 월별_매출액, Length: 10109, dtype: float64

# %% [markdown]
# ### 회사별 경영년도 구하기
# *  거의 절반의 회사(2411개)들이 1년차이고, 실제 유니콘 기업의 매출액과 비교하기 위해 최소 3년이상의 데이터가 있는 회사들만 선택함
# *  실제 유니콘들의 매출 데이터도 사람인에서 3년치만  있는 경우가 대부분이어서 이렇게 년차로 선택함

# %%
demo2=demo.reset_index().groupby('회사ID')['월별_매출액'].count()
demo2.sort_values(ascending=False)
# Out:
# 회사ID
# 134575.0    5
# 395238.0    5
# 237625.0    5
# 192812.0    5
# 442467.0    5
#            ..
# 308198.0    1
# 308130.0    1
# 307873.0    1
# 307818.0    1
# 63.0        1
# Name: 월별_매출액, Length: 4998, dtype: int64

# %%
demo2.value_counts().sort_index()
# Out:
# 1    2409
# 2     944
# 3     783
# 4     847
# 5      15
# Name: 월별_매출액, dtype: int64

# %%
demo2_1=demo2[demo2>2].reset_index()
demo2_1.회사ID.unique()
# Out:
# array([ 14271.,  59533., 122968., ..., 514934., 515264., 516653.])

# %%
# 1645개의 기업이 데이터상 3년차 이상인 기업임.
hy_comp= demo2_1.회사ID.unique()
len(hy_comp)
# Out:
# 1645

# %%
# 3년차 이상의 기업의 데이터
df_hycomp=df1.loc[df1.회사ID.isin(hy_comp),:]
df_hycomp
# Out:
#            회사ID        연매출액    year  month    월별_연금보험료  월별_직원수        월별_매출액  \
# 0      233757.0  41688077.0  2018.0    7.0   8912380.0    36.0  3.474006e+06
# 1      123464.0   1760695.0  2018.0    3.0    942380.0     5.0  1.467246e+05
# 3      386420.0   4815584.0  2015.0   11.0   3795900.0    14.0  4.012987e+05
# 4      129243.0   9799736.0  2018.0   10.0  40724680.0   151.0  8.166447e+05
# 7      189562.0   7119908.0  2016.0    1.0   1276900.0     6.0  5.933257e+05
# ...         ...         ...     ...    ...         ...     ...           ...
# 99793  199954.0   1651504.0  2016.0    1.0   1414960.0     6.0  1.376253e+05
# 99795  150135.0   7119441.0  2016.0   12.0   4872520.0    25.0  5.932868e+05
# 99796  171439.0   4630622.0  2017.0    2.0   2402740.0    11.0  3.858852e+05
# 99799  362194.0   2100218.0  2018.0   12.0    874780.0     3.0  1.750182e+05
# 99800  124281.0    132900.0  2017.0   11.0    291940.0     5.0  1.107500e+04
#
#        day       date      월별_직원별보험료      월별직원별매출액  월별_보험료별매출액  anomaly
# 0      1.0 2018-07-01  247566.111111  96500.178241    0.389796      1.0
# 1      1.0 2018-03-01  188476.000000  29344.916667    0.155696      1.0
# 3      1.0 2015-11-01  271135.714286  28664.190476    0.105719      1.0
# 4      1.0 2018-10-01  269699.867550   5408.242826    0.020053      1.0
# 7      1.0 2016-01-01  212816.666667  98887.611111    0.464661      1.0
# ...    ...        ...            ...           ...         ...      ...
# 99793  1.0 2016-01-01  235826.666667  22937.555556    0.097264      NaN
# 99795  1.0 2016-12-01  194900.800000  23731.470000    0.121762      NaN
# 99796  1.0 2017-02-01  218430.909091  35080.469697    0.160602      NaN
# 99799  1.0 2018-12-01  291593.333333  58339.388889    0.200071      NaN
# 99800  1.0 2017-11-01   58388.000000   2215.000000    0.037936      NaN
#
# [56023 rows x 13 columns]

# %%
df_f_y_sal=df_hycomp.sort_values(['회사ID','date']).groupby(['회사ID','year'])['월별_매출액'].sum()
df_f_y_sal=df_f_y_sal.reset_index()

# %%
df_f_y_sal.columns=['회사ID','year','매출액']
df_f_y_sal
# Out:
#           회사ID    year           매출액
# 0      14271.0  2015.0  1.999158e+05
# 1      14271.0  2016.0  4.257715e+06
# 2      14271.0  2017.0  5.005248e+06
# 3      14271.0  2018.0  8.388401e+06
# 4      14271.0  2019.0  9.039340e+06
# ...        ...     ...           ...
# 5807  515264.0  2017.0  2.074820e+06
# 5808  515264.0  2018.0  2.422405e+06
# 5809  516653.0  2016.0  1.745520e+06
# 5810  516653.0  2017.0  1.956460e+06
# 5811  516653.0  2018.0  1.125034e+06
#
# [5812 rows x 3 columns]

# %%
g_sal=[]
df_f_id=df_f_y_sal.loc[:,'회사ID']
df_f_sal=df_f_y_sal.loc[:,'매출액']

# %%
# 같은 회사ID에서 매출성장률 측정
a1=[]
for i in np.arange(df_f_y_sal.shape[0]):
    if (df_f_id.values[i] == df_f_id.values[i-1]):
        a1.append((df_f_sal[i] - df_f_sal[i-1])/df_f_sal[i-1]*100)
    else :
#  -11.72259828086512,
#  0,
#  422.0916959011862,
#  24.1357365611938,
#  -1.1868649698426355,
#  0,
#  2098.396775503452,
#  -31.580227589356475,
#  203.2369564077428,
#  0,
#  -2.0652092439853087,
#  -2.062595760779582,
#  0,
#  438.26868374878904,
#  12.223195357930157,
#  7.244604012244905,
#  0,
#  706.1488596118609,
#  8.016539389719757,
#  8.060235643619261,
#  0,
#  594.4049550260866,
#  -4.678993912871665,
#  -0.17697742764922428,
#  0,
#  540.7460101297106,
#  11.477351746783551,
#  16.03718760607433,
#  0,
#  413.6761447502879,
#  -0.0058985783037018985,
#  0,
#  640.4644545246294,
#  -0.8806283374427024,
#  -8.951551055707473,
#  0,
#  419.7888274499255,
#  8.995710435250388,
#  4.988357445835825,
#  0,
#  33.89540616753938,
#  30.74226496686138,
#  0,
#  507.18678370997645,
#  72.31677455769999,
#  -68.11461757520219,
#  0,
#  517.4012913450186,
#  5.168130688466632,
#  16.64290601785846,
#  0,
#  443.67920379367246,
#  27.848007113192086,
#  -13.038403173487717,
#  0,
#  -1.7805839661253682,
#  28.23269994487383,
#  ...]

# %%
len(a1)
# Out:
# 5812

# %%
df_f_y_sal.shape
# Out:
# (5812, 3)

# %%
df_f_y_sal['매출액성장률']=a1
df_f_y_sal
# Out:
#           회사ID    year           매출액       매출액성장률
# 0      14271.0  2015.0  1.999158e+05     0.000000
# 1      14271.0  2016.0  4.257715e+06  2029.753771
# 2      14271.0  2017.0  5.005248e+06    17.557140
# 3      14271.0  2018.0  8.388401e+06    67.592115
# 4      14271.0  2019.0  9.039340e+06     7.759989
# ...        ...     ...           ...          ...
# 5807  515264.0  2017.0  2.074820e+06    39.313150
# 5808  515264.0  2018.0  2.422405e+06    16.752538
# 5809  516653.0  2016.0  1.745520e+06     0.000000
# 5810  516653.0  2017.0  1.956460e+06    12.084651
# 5811  516653.0  2018.0  1.125034e+06   -42.496422
#
# [5812 rows x 4 columns]

# %% [markdown]
# *  아래는 따로 가진 cb인사이트 기준으로 선정된 유니콘 기업의 매출액 데이터를 사람인에서 가져옴
#
# *  절대적인 매출액 수치는 의미가 없으므로, 매출액 성장률을 살펴보는 것이 의미가 있을 것으로 추정함

# %%
uni_data=pd.read_csv('유니콘기업매출액.csv',encoding='euc-kr')
uni_data
# Out:
#       년도          기업명             매출액          성장률       평균성장률
# 0   2015           쿠팡   1133700000000          NaN         NaN
# 1   2016           쿠팡   1915900000000    68.995325         NaN
# 2   2017           쿠팡   2684600000000    40.122136         NaN
# 3   2018           쿠팡   4435400000000    65.216420         NaN
# 4   2019           쿠팡   7153000000000    61.270686         NaN
# 5   2020           쿠팡  13300000000000    85.935971   64.308107
# 6   2018         크래프톤     20000000000          NaN         NaN
# 7   2019         크래프톤     12000000000   -40.000000         NaN
# 8   2020         크래프톤     95000000000   691.666667  325.833333
# 9   2017      바비리퍼블리카     20591080000          NaN         NaN
# 10  2018      바비리퍼블리카     54820880000   166.236060         NaN
# 11  2019      바비리퍼블리카    118730970000   116.579832         NaN
# 12  2020      바비리퍼블리카    176622390000    48.758483  110.524792
# 13  2018          위메프    429431110000          NaN         NaN
# 14  2019          위메프    465340580000     8.362103         NaN
# 15  2020          위메프    385342280000   -17.191344   -4.414621
# 16  2017          무신사     67721260000          NaN         NaN
# 17  2018          무신사     10816420000   -84.028029         NaN
# 18  2019          무신사    210312760000  1844.384186         NaN
# 19  2020          무신사    300915710000    43.080101  601.145420
# 20  2017         지피클럽     49755790000          NaN         NaN
# 21  2018         지피클럽    513728710000   932.500358         NaN
# 22  2019         지피클럽    448642100000   -12.669452         NaN
# 23  2020         지피클럽    401690120000   -10.465353  303.121851
# 24  2017      엘엔피코스메틱    315572300000          NaN         NaN
# 25  2018      엘엔피코스메틱    314078750000    -0.473283         NaN
# 26  2019      엘엔피코스메틱    178190160000   -43.265770         NaN
# 27  2020      엘엔피코스메틱    174655110000    -1.983864  -15.240972
# 28  2018  에이프로젠바이오로직스      5497440000          NaN         NaN
# 29  2019  에이프로젠바이오로직스     10848740000    97.341672         NaN
# 30  2020  에이프로젠바이오로직스     14525350000    33.889742   65.615707
# 31  2017          야놀자     54527870000          NaN         NaN
# 32  2018          야놀자     73884860000    35.499259         NaN
# 33  2019          야놀자    151377460000   104.882922         NaN
# 34  2020          야놀자    191570550000    26.551569   55.644583

# %%
# 유니콘업체들의 평균 매출 성장률
given_rate=uni_data.평균성장률.mean()
given_rate
# Out:
# 167.39313336611113

# %% [markdown]
# ### cb 인사이트에 뽑힌 유니콘 기업의 평균 매출 성장률보다 큰 매출성장률을 가진 기업들을 필터링
# ### 해당 기업들을 f_id_demo에 별도로 저장

# %%
df_demo=df_f_y_sal.loc[df_f_y_sal['매출액성장률']>given_rate,:]
f_id_demo=df_demo.회사ID.unique()
len(f_id_demo)
# Out:
# 1335

# %% [markdown]
# ## Route 2: IsolationFroest를 기반으로 추출한 outliers와 매출액을 직원별, 보험료별로 조정한
# ##                변수로 추정한 상위 0.01%에 해당하는 기업에 공통으로 해당되는 기업들을
# ##                유니콘기업으로 보는 방식으로 기업 목록을 추출함

# %%
# 월별_직원수는 -값이 없는 것으로 보아 올바른 데이터임
df1.월별_직원수.describe()
# Out:
# count    99801.000000
# mean        37.623431
# std        146.947194
# min          0.000000
# 25%          6.000000
# 50%         11.000000
# 75%         24.000000
# max       3133.000000
# Name: 월별_직원수, dtype: float64

# %%
df1.월별_직원수.hist()

# %% [markdown]
# ### 매출액을 직원수로 나눠서 직원이 기여하는 매출액을 추정한다
# ### 매출액을 연금보험료로 나눠서 기업이 지급하는 임금이 매출액에 얼마나 기여하는지 추정한다.

# %%
df1['월별직원별매출액']=df1.월별_매출액/df1.월별_직원수
df1
# Out:
#          회사ID      연매출액  year  month  월별_연금보험료  월별_직원수        월별_매출액  day  \
# 0      233757  41688077  2018      7   8912380      36  3.474006e+06    1
# 1      123464   1760695  2018      3    942380       5  1.467246e+05    1
# 2      342124   3221341  2018      7    781180       4  2.684451e+05    1
# 3      386420   4815584  2015     11   3795900      14  4.012987e+05    1
# 4      129243   9799736  2018     10  40724680     151  8.166447e+05    1
# ...       ...       ...   ...    ...       ...     ...           ...  ...
# 99796  171439   4630622  2017      2   2402740      11  3.858852e+05    1
# 99797  239388   1045021  2018     10   1428800       9  8.708508e+04    1
# 99798  272304    181898  2018      3    392560       4  1.515817e+04    1
# 99799  362194   2100218  2018     12    874780       3  1.750182e+05    1
# 99800  124281    132900  2017     11    291940       5  1.107500e+04    1
#
#             date      월별_직원별보험료      월별직원별매출액
# 0     2018-07-01  247566.111111  96500.178241
# 1     2018-03-01  188476.000000  29344.916667
# 2     2018-07-01  195295.000000  67111.270833
# 3     2015-11-01  271135.714286  28664.190476
# 4     2018-10-01  269699.867550   5408.242826
# ...          ...            ...           ...
# 99796 2017-02-01  218430.909091  35080.469697
# 99797 2018-10-01  158755.555556   9676.120370
# 99798 2018-03-01   98140.000000   3789.541667
# 99799 2018-12-01  291593.333333  58339.388889
# 99800 2017-11-01   58388.000000   2215.000000
#
# [99801 rows x 11 columns]

# %%
df1['월별_보험료별매출액']=df1.월별_매출액/df1.월별_연금보험료
df1
# Out:
#          회사ID      연매출액  year  month  월별_연금보험료  월별_직원수        월별_매출액  day  \
# 0      233757  41688077  2018      7   8912380      36  3.474006e+06    1
# 1      123464   1760695  2018      3    942380       5  1.467246e+05    1
# 2      342124   3221341  2018      7    781180       4  2.684451e+05    1
# 3      386420   4815584  2015     11   3795900      14  4.012987e+05    1
# 4      129243   9799736  2018     10  40724680     151  8.166447e+05    1
# ...       ...       ...   ...    ...       ...     ...           ...  ...
# 99796  171439   4630622  2017      2   2402740      11  3.858852e+05    1
# 99797  239388   1045021  2018     10   1428800       9  8.708508e+04    1
# 99798  272304    181898  2018      3    392560       4  1.515817e+04    1
# 99799  362194   2100218  2018     12    874780       3  1.750182e+05    1
# 99800  124281    132900  2017     11    291940       5  1.107500e+04    1
#
#             date      월별_직원별보험료      월별직원별매출액  월별_보험료별매출액
# 0     2018-07-01  247566.111111  96500.178241    0.389796
# 1     2018-03-01  188476.000000  29344.916667    0.155696
# 2     2018-07-01  195295.000000  67111.270833    0.343640
# 3     2015-11-01  271135.714286  28664.190476    0.105719
# 4     2018-10-01  269699.867550   5408.242826    0.020053
# ...          ...            ...           ...         ...
# 99796 2017-02-01  218430.909091  35080.469697    0.160602
# 99797 2018-10-01  158755.555556   9676.120370    0.060950
# 99798 2018-03-01   98140.000000   3789.541667    0.038614
# 99799 2018-12-01  291593.333333  58339.388889    0.200071
# 99800 2017-11-01   58388.000000   2215.000000    0.037936
#
# [99801 rows x 12 columns]

# %%
# 원데이터에서 월별 보험료와 직원수가 모두 0인 데이터가 발견됨. 그런데 매출액은 나옴
# 15년과 19년데이터는 없음
df1.loc[df1.월별직원별매출액==np.inf,:]
# 보험료와 직원수가 0인 데이터를 어떻게 처리할 것인가라는 것이 문제임
# 치환? 삭제?(보험료가 직원수가 0인 기업은 오류이거나 1인 기업일 가능성이 있으므로 유니콘 기업의 추정에서 제외함 )
df1.loc[df1.월별직원별매출액==np.inf,:]=df1.loc[df1.월별직원별매출액==np.inf,:].replace(np.inf,np.nan)
df1=df1.dropna()

# %%
df1_iso=df1.iloc[:,9:].copy()
df1_iso['월별_직원별보험료']=df1_iso['월별_직원별보험료'].fillna(0)

# %%
df1_iso['년도']=df1['year']
df1_iso['월']=df1['month']

# %%
df1_iso.isnull().sum()
# Out:
# 월별_직원별보험료     0
# 월별직원별매출액      0
# 월별_보험료별매출액    0
# 년도            0
# 월             0
# dtype: int64

# %%
df1_iso
# Out:
#            월별_직원별보험료      월별직원별매출액  월별_보험료별매출액    년도   월
# 0      247566.111111  96500.178241    0.389796  2018   7
# 1      188476.000000  29344.916667    0.155696  2018   3
# 2      195295.000000  67111.270833    0.343640  2018   7
# 3      271135.714286  28664.190476    0.105719  2015  11
# 4      269699.867550   5408.242826    0.020053  2018  10
# ...              ...           ...         ...   ...  ..
# 99796  218430.909091  35080.469697    0.160602  2017   2
# 99797  158755.555556   9676.120370    0.060950  2018  10
# 99798   98140.000000   3789.541667    0.038614  2018   3
# 99799  291593.333333  58339.388889    0.200071  2018  12
# 99800   58388.000000   2215.000000    0.037936  2017  11
#
# [99788 rows x 5 columns]

# %%
df1_iso.describe()
# Out:
#            월별_직원별보험료      월별직원별매출액    월별_보험료별매출액            년도             월
# count   99788.000000  9.978800e+04  99788.000000  99788.000000  99788.000000
# mean   222542.478314  4.951728e+04      0.214463   2016.967140      6.714515
# std     64355.289384  1.231049e+05      0.504894      0.976691      3.512956
# min     26100.000000 -1.313696e+05     -0.389183   2015.000000      1.000000
# 25%    176628.571429  1.182327e+04      0.058156   2016.000000      4.000000
# 50%    223196.666667  2.384811e+04      0.110782   2017.000000      7.000000
# 75%    266722.500000  4.887500e+04      0.217552   2018.000000     10.000000
# max    479821.250000  4.232062e+06     21.872238   2019.000000     12.000000

# %%
from sklearn.ensemble import IsolationForest
model=IsolationForest(n_estimators=100, max_samples='auto', n_jobs=-1,
                      max_features=4, contamination=0.001)
model.fit(df1_iso.to_numpy())
# Out:
# IsolationForest(contamination=0.001, max_features=4, n_jobs=-1)

# %%
anomaly = model.predict(df1_iso.to_numpy())
anomaly=pd.Series(anomaly)
anomaly.name='anomaly'

# %%
anomaly.value_counts()
# Out:
#  1    99688
# -1      100
# Name: anomaly, dtype: int64

# %%
anomaly.shape
# Out:
# (99788,)

# %%
df1_iso.shape
# Out:
# (99788, 5)

# %%
df1.shape
# Out:
# (99788, 12)

# %%
df1=pd.concat([df1,anomaly],axis=1)

# %%
df1
# Out:
#            회사ID        연매출액    year  month    월별_연금보험료  월별_직원수        월별_매출액  \
# 0      233757.0  41688077.0  2018.0    7.0   8912380.0    36.0  3.474006e+06
# 1      123464.0   1760695.0  2018.0    3.0    942380.0     5.0  1.467246e+05
# 2      342124.0   3221341.0  2018.0    7.0    781180.0     4.0  2.684451e+05
# 3      386420.0   4815584.0  2015.0   11.0   3795900.0    14.0  4.012987e+05
# 4      129243.0   9799736.0  2018.0   10.0  40724680.0   151.0  8.166447e+05
# ...         ...         ...     ...    ...         ...     ...           ...
# 99796  171439.0   4630622.0  2017.0    2.0   2402740.0    11.0  3.858852e+05
# 99797  239388.0   1045021.0  2018.0   10.0   1428800.0     9.0  8.708508e+04
# 99798  272304.0    181898.0  2018.0    3.0    392560.0     4.0  1.515817e+04
# 99799  362194.0   2100218.0  2018.0   12.0    874780.0     3.0  1.750182e+05
# 99800  124281.0    132900.0  2017.0   11.0    291940.0     5.0  1.107500e+04
#
#        day       date      월별_직원별보험료      월별직원별매출액  월별_보험료별매출액  anomaly
# 0      1.0 2018-07-01  247566.111111  96500.178241    0.389796      1.0
# 1      1.0 2018-03-01  188476.000000  29344.916667    0.155696      1.0
# 2      1.0 2018-07-01  195295.000000  67111.270833    0.343640      1.0
# 3      1.0 2015-11-01  271135.714286  28664.190476    0.105719      1.0
# 4      1.0 2018-10-01  269699.867550   5408.242826    0.020053      1.0
# ...    ...        ...            ...           ...         ...      ...
# 99796  1.0 2017-02-01  218430.909091  35080.469697    0.160602      NaN
# 99797  1.0 2018-10-01  158755.555556   9676.120370    0.060950      NaN
# 99798  1.0 2018-03-01   98140.000000   3789.541667    0.038614      NaN
# 99799  1.0 2018-12-01  291593.333333  58339.388889    0.200071      NaN
# 99800  1.0 2017-11-01   58388.000000   2215.000000    0.037936      NaN
#
# [99801 rows x 13 columns]

# %%
df1_anomly=df1.loc[df1['anomaly']==-1,:]

# %%
id_anomaly=df1_anomly.회사ID.unique()

# %%
id_anomaly
# Out:
# array([146654., 297874., 433492., 277034., 259801., 345874., 292396.,
#        316311., 338722., 567664.,  78226., 241101., 300364., 381344.,
#        245286.,  93162., 310440., 127060., 251519., 132638., 166244.,
#        255236., 441523., 272896., 159657., 264808., 154322., 139676.,
#        250522., 310315., 367090., 298157., 312008., 233530., 314352.,
#        507346., 442613., 143946., 265240., 179207., 475796., 412928.,
#        386205., 262928., 145654., 314638., 156012., 470994., 354037.,
#        142248., 294367., 342218., 322239., 205018., 324894., 130729.,
#        236539., 272310., 160784., 232206., 132926.,  10881., 405004.,
#        442777., 131723., 254009., 319646., 135559., 129828., 416013.,
#        451016., 254399., 139716., 145999., 133041., 442908., 411214.,
#        228975., 349194., 427703., 295986., 478831., 250300., 141280.,
#        146761.,  14271., 232257., 179686., 131440., 445594., 555805.,
#        131872., 303781., 509060., 157929., 212252., 257336.])

# %%
len(id_anomaly)
# Out:
# 97

# %%
df1.월별_보험료별매출액.hist()

# %%
df1.월별_보험료별매출액.describe()
# Out:
# count    99788.000000
# mean         0.214463
# std          0.504894
# min         -0.389183
# 25%          0.058156
# 50%          0.110782
# 75%          0.217552
# max         21.872238
# Name: 월별_보험료별매출액, dtype: float64

# %%
df1.월별_보험료별매출액.quantile(0.998)
# Out:
# 4.981187146767152

# %%
id_s_is=df1.loc[df1.월별_보험료별매출액>4.98,:].회사ID.unique()
id_s_is
# Out:
# array([426180., 439585., 146654., 297874., 101711., 433492.,  40860.,
#        102971., 260890., 567650., 382850., 157237.,  67616., 430504.,
#        288613., 430507., 429453., 434348.])

# %%
df1.월별직원별매출액.hist()

# %%
df1.월별직원별매출액.describe()
# Out:
# count    9.978800e+04
# mean     4.951728e+04
# std      1.231049e+05
# min     -1.313696e+05
# 25%      1.182327e+04
# 50%      2.384811e+04
# 75%      4.887500e+04
# max      4.232062e+06
# Name: 월별직원별매출액, dtype: float64

# %%
sal_emp=df1['월별직원별매출액'].quantile(0.997)

# %%
id_s_epl=df1.loc[df1['월별직원별매출액']>round(sal_emp,2),:].회사ID.unique()
id_s_epl
# Out:
# array([426180., 294649., 439585., 146654., 297874., 101711., 430504.,
#        433492., 432911., 428817.,  40860., 102971., 260890., 567650.,
#        382850., 433756.,  67616., 288613., 430507., 434348.])

# %%
df1.월별_직원별보험료.describe()
# Out:
# count     99788.000000
# mean     222542.478314
# std       64355.289384
# min       26100.000000
# 25%      176628.571429
# 50%      223196.666667
# 75%      266722.500000
# max      479821.250000
# Name: 월별_직원별보험료, dtype: float64

# %%
ins_emp=df1.월별_직원별보험료.quantile(0.997)

# %%
id_epl_is=df1.loc[df1['월별_직원별보험료']>round(ins_emp,2),:].회사ID.unique()
id_epl_is
# Out:
# array([4.203040e+05, 3.312354e+06, 2.282930e+05, 1.888280e+05,
#        9.500000e+01, 3.370730e+05, 2.833800e+05, 2.523630e+05,
#        1.268310e+05, 1.475460e+05, 1.132630e+05, 4.165070e+05,
#        4.424390e+05, 2.917100e+04, 4.413300e+05, 6.300000e+01,
#        2.934020e+05, 2.946490e+05, 3.811800e+05, 4.436980e+05,
#        3.891450e+05, 1.973220e+05, 2.316250e+05, 4.034620e+05,
#        4.205730e+05, 4.200080e+05, 2.970770e+05, 6.015400e+04,
#        2.274150e+05, 8.161900e+04, 5.452000e+03, 2.830210e+05,
#        1.463810e+05, 4.225000e+05, 4.199980e+05, 1.394800e+04,
#        2.020770e+05, 4.201650e+05, 4.337560e+05, 2.274140e+05,
#        5.579760e+05, 1.063460e+05, 1.153890e+05, 3.402900e+04,
#        3.274050e+05, 2.392830e+05, 5.196900e+04, 2.842000e+03,
#        1.965490e+05, 3.069400e+04, 6.301900e+05, 3.947490e+05,
#        2.909100e+04])

# %%
id_s_epl #직원별 매출액
# Out:
# array([426180., 294649., 439585., 146654., 297874., 101711., 430504.,
#        433492., 432911., 428817.,  40860., 102971., 260890., 567650.,
#        382850., 433756.,  67616., 288613., 430507., 434348.])

# %%
id_s_is #보험료별 매출액
# Out:
# array([426180., 439585., 146654., 297874., 101711., 433492.,  40860.,
#        102971., 260890., 567650., 382850., 157237.,  67616., 430504.,
#        288613., 430507., 429453., 434348.])

# %%
list1=[]
for i in id_s_epl:
    if i in id_s_is:
        list1.append(i)

list1
# Out:
# [426180.0,
#  439585.0,
#  146654.0,
#  297874.0,
#  101711.0,
#  430504.0,
#  433492.0,
#  40860.0,
#  102971.0,
#  260890.0,
#  567650.0,
#  382850.0,
#  67616.0,
#  288613.0,
#  430507.0,
#  434348.0]

# %%
len(list1)
# 14개 기업을 직원별 보험료별 매출액으로 이상값으로 판단함
# Out:
# 16

# %%
# 직원별 보험료로 고려한 상위 그룹은 매출액과 관련된 지표의 상위그룹과 곂치는 회사가 없음
list_fin=[]
for i in list1:
    if i in id_epl_is:
        list_fin.append(i)

list_fin
# Out:
# []

# %%
id_epl_is
# Out:
# array([4.203040e+05, 3.312354e+06, 2.282930e+05, 1.888280e+05,
#        9.500000e+01, 3.370730e+05, 2.833800e+05, 2.523630e+05,
#        1.268310e+05, 1.475460e+05, 1.132630e+05, 4.165070e+05,
#        4.424390e+05, 2.917100e+04, 4.413300e+05, 6.300000e+01,
#        2.934020e+05, 2.946490e+05, 3.811800e+05, 4.436980e+05,
#        3.891450e+05, 1.973220e+05, 2.316250e+05, 4.034620e+05,
#        4.205730e+05, 4.200080e+05, 2.970770e+05, 6.015400e+04,
#        2.274150e+05, 8.161900e+04, 5.452000e+03, 2.830210e+05,
#        1.463810e+05, 4.225000e+05, 4.199980e+05, 1.394800e+04,
#        2.020770e+05, 4.201650e+05, 4.337560e+05, 2.274140e+05,
#        5.579760e+05, 1.063460e+05, 1.153890e+05, 3.402900e+04,
#        3.274050e+05, 2.392830e+05, 5.196900e+04, 2.842000e+03,
#        1.965490e+05, 3.069400e+04, 6.301900e+05, 3.947490e+05,
#        2.909100e+04])

# %%
list1
# Out:
# [426180.0,
#  439585.0,
#  146654.0,
#  297874.0,
#  101711.0,
#  430504.0,
#  433492.0,
#  40860.0,
#  102971.0,
#  260890.0,
#  567650.0,
#  382850.0,
#  67616.0,
#  288613.0,
#  430507.0,
#  434348.0]

# %%
list_fin=[]
for i in list1:
    if i in id_anomaly:
        list_fin.append(i)
list_fin
# isoforest로 구한 이상값에 해당하는 회사들과 직원별, 보험료별 매출액의 상위기업들 중 다음 기업들이 일치함
# 즉, 상위 0.2%에 해당하는 직원별, 보험료별 매출액에 해당하는 기업들이 isoforest를 기반으로한 이상값탐색에서의 이상값과 일치하는 기업으로
# 이들을 유니콘 기업으로 파악함
# Out:
# [146654.0, 297874.0, 433492.0]

# %%
unic_comp=df1.loc[df1.회사ID.isin(list_fin),:]
unic_comp=unic_comp.iloc[:,:-1]

# %%
u_f=unic_comp.회사ID.unique()
u_f
# Out:
# array([146654., 297874., 433492.])

# %%
len(u_f)
# Out:
# 3

# %%
unic_comp.describe()
# Out:
#                 회사ID          연매출액         year       month      월별_연금보험료  \
# count     102.000000  1.020000e+02   102.000000  102.000000  1.020000e+02
# mean   276106.431373  6.961504e+08  2016.764706    6.794118  6.659041e+06
# std    113400.739112  4.459627e+08     0.880779    3.569226  3.444825e+06
# min    146654.000000  4.008298e+07  2015.000000    1.000000  6.813800e+05
# 25%    146654.000000  2.683306e+08  2016.000000    4.000000  2.856305e+06
# 50%    297874.000000  6.517537e+08  2017.000000    7.000000  8.741750e+06
# 75%    399587.500000  9.839046e+08  2017.000000   10.000000  8.940680e+06
# max    433492.000000  1.501349e+09  2018.000000   12.000000  1.042306e+07
#
#            월별_직원수        월별_매출액    day      월별_직원별보험료      월별직원별매출액  \
# count  102.000000  1.020000e+02  102.0     102.000000  1.020000e+02
# mean    24.901961  5.801253e+07    1.0  269054.033278  2.281153e+06
# std     13.490378  3.716355e+07    0.0   56710.197654  8.327415e+05
# min      3.000000  3.340248e+06    1.0  195849.375000  5.567081e+05
# 25%     10.500000  2.236088e+07    1.0  218405.365854  1.929423e+06
# 50%     27.000000  5.431281e+07    1.0  246817.566783  2.213475e+06
# 75%     33.000000  8.199205e+07    1.0  330936.296296  2.664933e+06
# max     45.000000  1.251124e+08    1.0  364313.333333  4.232062e+06
#
#        월별_보험료별매출액
# count  102.000000
# mean     9.193906
# std      4.562712
# min      1.890971
# 25%      5.839029
# 50%      8.932388
# 75%     12.603991
# max     18.633049

# %%
l_lab=[]
for i in range(df1.shape[0]):
    if df1.회사ID[i] in u_f:
        l_lab.append('uni')
    else:
        l_lab.append('normal')

l_lab
# Out:
# ['normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  ...]

# %%
len(l_lab)
# Out:
# 99801

# %%
pd.Series(l_lab).shape
# Out:
# (99801,)

# %%
df1=pd.concat([df1,pd.Series(l_lab)],axis=1)
col_fin=df1.columns.values
col_fin[-1]='label'

# %%
df1
# Out:
#            회사ID        연매출액    year  month    월별_연금보험료  월별_직원수        월별_매출액  \
# 0      233757.0  41688077.0  2018.0    7.0   8912380.0    36.0  3.474006e+06
# 1      123464.0   1760695.0  2018.0    3.0    942380.0     5.0  1.467246e+05
# 2      342124.0   3221341.0  2018.0    7.0    781180.0     4.0  2.684451e+05
# 3      386420.0   4815584.0  2015.0   11.0   3795900.0    14.0  4.012987e+05
# 4      129243.0   9799736.0  2018.0   10.0  40724680.0   151.0  8.166447e+05
# ...         ...         ...     ...    ...         ...     ...           ...
# 99796  171439.0   4630622.0  2017.0    2.0   2402740.0    11.0  3.858852e+05
# 99797  239388.0   1045021.0  2018.0   10.0   1428800.0     9.0  8.708508e+04
# 99798  272304.0    181898.0  2018.0    3.0    392560.0     4.0  1.515817e+04
# 99799  362194.0   2100218.0  2018.0   12.0    874780.0     3.0  1.750182e+05
# 99800  124281.0    132900.0  2017.0   11.0    291940.0     5.0  1.107500e+04
#
#        day       date      월별_직원별보험료      월별직원별매출액  월별_보험료별매출액  anomaly  \
# 0      1.0 2018-07-01  247566.111111  96500.178241    0.389796      1.0
# 1      1.0 2018-03-01  188476.000000  29344.916667    0.155696      1.0
# 2      1.0 2018-07-01  195295.000000  67111.270833    0.343640      1.0
# 3      1.0 2015-11-01  271135.714286  28664.190476    0.105719      1.0
# 4      1.0 2018-10-01  269699.867550   5408.242826    0.020053      1.0
# ...    ...        ...            ...           ...         ...      ...
# 99796  1.0 2017-02-01  218430.909091  35080.469697    0.160602      NaN
# 99797  1.0 2018-10-01  158755.555556   9676.120370    0.060950      NaN
# 99798  1.0 2018-03-01   98140.000000   3789.541667    0.038614      NaN
# 99799  1.0 2018-12-01  291593.333333  58339.388889    0.200071      NaN
# 99800  1.0 2017-11-01   58388.000000   2215.000000    0.037936      NaN
#
#         label
# 0      normal
# 1      normal
# 2      normal
# 3      normal
# 4      normal
# ...       ...
# 99796  normal
# 99797  normal
# 99798  normal
# 99799  normal
# 99800  normal
#
# [99801 rows x 14 columns]

# %%
df1.iloc[:,8:12].describe()
# Out:
#            월별_직원별보험료      월별직원별매출액    월별_보험료별매출액
# count   99788.000000  9.978800e+04  99788.000000
# mean   222542.478314  4.951728e+04      0.214463
# std     64355.289384  1.231049e+05      0.504894
# min     26100.000000 -1.313696e+05     -0.389183
# 25%    176628.571429  1.182327e+04      0.058156
# 50%    223196.666667  2.384811e+04      0.110782
# 75%    266722.500000  4.887500e+04      0.217552
# max    479821.250000  4.232062e+06     21.872238

# %% [markdown]
# ### cb인사이트와 사람인 기준 유니콘데이터의 매출액 성장률을 추가변수를 저장한 데이터프레임에 다시 적용함

# %%
df_demo=df1.loc[df1.회사ID.isin(f_id_demo),:]

# %% [markdown]
# ### 아웃라이어와 원 데이터의 추가변수 상위값 기준으로 정한 유니콘 기업의 하위 10%에서 상위 90%까지에 해당하는
# ### 직원별 매출액,보험료별 매출액에 해당하는 데이터들을 위 df_demo에서 구함

# %%
df_demo2=df_demo.loc[df_demo.월별_보험료별매출액 > unic_comp.월별_보험료별매출액.quantile(0.10)].loc[df_demo.월별_보험료별매출액 
                                                                    < unic_comp.월별_보험료별매출액.quantile(0.90)]

# %%
df_demo3=df_demo2.loc[df_demo2.월별직원별매출액 > unic_comp.월별직원별매출액.quantile(0.10)].loc[df_demo2.월별직원별매출액 
                                                                  < unic_comp.월별직원별매출액.quantile(0.90)]

# %% [markdown]
# ### 최종적을 다음의 6개의 기업이 유니콘 기업에 해당함

# %%
df_demo3.회사ID.unique()
# Out:
# array([439585., 146654., 297874., 382850., 430504., 433492.])

# %% [markdown]
# ## 이하는 개인적 연습용 작업입니다.

# %%
# 상식처럼 연금보험료와 직원수는 양의 상관관계를 보임
plt.scatter(df1.월별_연금보험료,df1.월별_직원수)

# %%
plt.scatter(df1.월별_보험료별매출액,df1.월별직원별매출액)

# %%
df1.월별_직원별보험료.hist()
# Out:
# <AxesSubplot:>

# %%
# 직원들의 임금과 연매출액에는 상관관계가 눈에 보이지 않음
plt.scatter(df1.월별_직원별보험료,df1.연매출액)

# %%
high_sal_df=df1.loc[df1.월별_직원별보험료 > 300000,:]
high_sal_df.회사ID.unique().shape
# 월별직원별 보험료가 300000넘는 기업은 전체 50000개중 885개에 해당함
# Out:
# (885,)

# %%
high_sal_df
# Out:
#           회사ID         연매출액  year  month   월별_연금보험료  월별_직원수  day       date  \
# 33039       63  11328779396  2018      1  403119840    1006    1 2018-01-01
# 74251       63  11328779396  2018      2  406770960    1018    1 2018-02-01
# 80947       63  11328779396  2018      3  404826240    1013    1 2018-03-01
# 80770       63  11328779396  2018      4  404211800    1012    1 2018-04-01
# 28110       63  11328779396  2018      5  400339640    1002    1 2018-05-01
# ...        ...          ...   ...    ...        ...     ...  ...        ...
# 47412  3312354      1451563  2019      8    1312200       3    1 2019-08-01
# 244    3312354      1451563  2019      9    1312200       3    1 2019-09-01
# 38757  3312354      1451563  2019     10    1312200       3    1 2019-10-01
# 49019  3312354      1451563  2019     11    1312200       3    1 2019-11-01
# 72163  3312354      1451563  2019     12    1312200       3    1 2019-12-01
#
#            월별_직원별보험료
# 33039  400715.546720
# 74251  399578.546169
# 80947  399631.036525
# 80770  399418.774704
# 28110  399540.558882
# ...              ...
# 47412  437400.000000
# 244    437400.000000
# 38757  437400.000000
# 49019  437400.000000
# 72163  437400.000000
#
# [11383 rows x 9 columns]

# %%
# 년도별 데이터 히스토그램 : 2016년과 2018년에 제일 많음
df1.year.hist()
# Out:
# <AxesSubplot:>

# %%
# 국민연금보험료는 년도 별로 최고보험료와 최저보험료를 별도로 산정한다.

# %%
# 연매출액을 카테고리화 하기
# 크기 조정( 1만원 단위)
df1['연매출액']=df1.연매출액/10000
df1['연매출액']
# Out:
# 0        4168.8077
# 1         176.0695
# 2         322.1341
# 3         481.5584
# 4         979.9736
#            ...
# 99796     463.0622
# 99797     104.5021
# 99798      18.1898
# 99799     210.0218
# 99800      13.2900
# Name: 연매출액, Length: 99801, dtype: float64

# %%
df1.연매출액.hist()
# Out:
# <AxesSubplot:>

# %%
df1.연매출액.describe()
# Out:
# count    9.980100e+04
# mean     3.053589e+03
# std      3.016647e+04
# min     -7.882176e+02
# 25%      1.409760e+02
# 50%      3.573585e+02
# 75%      9.582321e+02
# max      1.132878e+06
# Name: 연매출액, dtype: float64

# %%
sales_cat=pd.cut(df1.연매출액,bins=[-8,141,358,959,np.inf],labels=['D','C','B','A'])
df1['cat']=sales_cat
df1.cat.hist()
# Out:
# <AxesSubplot:>

# %%
id_counts=df1.회사ID.value_counts()
id_counts
# Out:
# 250472     50
# 404192     50
# 128174     50
# 395238     50
# 135668     50
#            ..
# 246979      1
# 105360      1
# 287627      1
# 573329      1
# 1983879     1
# Name: 회사ID, Length: 5000, dtype: int64

# %%
id_counts.hist()
# Out:
# <AxesSubplot:>

# %%
df1.년도.unique()
# 년도는 15년부터 19년까지 존재함
# Out:
# array([2018, 2015, 2016, 2017, 2019], dtype=int64)

# %%
# 50건이상 있는 회사들의 id 출력
over_50_groups=id_counts[id_counts>49].index

# %%
# 5천개의 기업중에 50번나오는 기업이 14개임(측정시작부터 마지막까지의 데이터가 있는 기업)
# 4년*12개월+2개월 = 50개 맞음
len(over_50_groups)
# Out:
# 14

# %%
df1.date.max()
# Out:
# Timestamp('2019-12-01 00:00:00')

# %%
df1.date.min()
# Out:
# Timestamp('2015-11-01 00:00:00')

# %%
id_counts[id_counts<49].index
# Out:
# Int64Index([ 192812,  478922,  303882,  165163,  419945,  280967,  317331,
#              240785,  441565,  249371,
#             ...
#              126413,  161535,  275473,  414585,  571871,  246979,  105360,
#              287627,  573329, 1983879],
#            dtype='int64', length=4986)

# %%
# 50건이상 데이터가 있는 회사들의 년도 출력
df1.loc[df1.회사ID==250472,'년도'].unique()
#df1.loc[df1.회사ID==404192,'년도'].unique()
# Out:
# array([2015, 2017, 2016, 2018, 2019], dtype=int64)
